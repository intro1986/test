# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Векторы
norm = np.random.normal(loc=0, scale=1, size=1000)
binom = np.random.binomial(n=10, p=0.5, size=1000)
unif = np.random.uniform(low=0, high=1, size=1000)
pois = np.random.poisson(lam=1, size=1000)
exp = np.random.exponential(scale=1, size=1000)

# %%
# DataFrame
df = pd.DataFrame({'norm': norm, 'binom': binom, 'unif': unif, 'pois': pois, 'exp': exp})
df.head()
# Out:
#        norm  binom      unif  pois       exp
# 0 -0.205036      6  0.916734     2  0.147273
# 1 -0.622038      4  0.556324     1  1.578451
# 2 -1.451771      3  0.233866     4  0.460615
# 3  2.922962      5  0.916048     1  0.147782
# 4 -0.434913      4  0.756097     1  0.800096

# %%
df.shape
# Out:
# (1000, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   norm    1000 non-null   float64
#  1   binom   1000 non-null   int64
#  2   unif    1000 non-null   float64
#  3   pois    1000 non-null   int64
#  4   exp     1000 non-null   float64
# dtypes: float64(3), int64(2)
# memory usage: 39.2 KB
